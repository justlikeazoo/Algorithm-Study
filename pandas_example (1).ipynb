# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1번 ~ 2번 문제
#
# - 붓꽃 데이터 활용
# (지난 주와 동일한 데이터, 다른 형태)

# %%
## 3번 ~ 5번 문제

- 이전 시즌의 클럽 축구 경기 데이터 활용
- 컬럼 명세서 : https://github.com/fivethirtyeight/data/tree/master/soccer-spi
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
## 데이터 불러오기
df = pd.read_csv("https://raw.githubusercontent.com/minsuk1003/Python_DA_Study/main/Week%202/spi_matches_latest.csv")
df.head()
# Out:
#    season        date  league_id                league                 team1  \
# 0    2019  2019-03-01       1979  Chinese Super League       Shandong Luneng
# 1    2019  2019-03-01       1979  Chinese Super League    Shanghai Greenland
# 2    2019  2019-03-01       1979  Chinese Super League  Guangzhou Evergrande
# 3    2019  2019-03-01       1979  Chinese Super League            Wuhan Zall
# 4    2019  2019-03-01       1979  Chinese Super League       Chongqing Lifan
#
#                team2   spi1   spi2   prob1   prob2  ...  importance1  \
# 0      Guizhou Renhe  48.22  37.83  0.5755  0.1740  ...         45.9
# 1      Shanghai SIPG  39.81  60.08  0.2387  0.5203  ...         25.6
# 2  Tianjin Quanujian  65.59  39.99  0.7832  0.0673  ...         77.1
# 3      Beijing Guoan  32.25  54.82  0.2276  0.5226  ...         35.8
# 4       Guangzhou RF  38.24  40.45  0.4403  0.2932  ...         26.2
#
#    importance2  score1  score2   xg1   xg2  nsxg1  nsxg2  adj_score1  \
# ...

# %% [markdown]
# ### 3-1. 데이터프레임의 모든 컬럼을 출력하고, ["season", "date", "league", "team1", "team2", "score1", "score2"] 컬럼만 지정하여 데이터프레임을 업데이트하시오.

# %%
## 밑에 코드 작성
# 데이터 불러오기
df = pd.read_csv("https://raw.githubusercontent.com/minsuk1003/Python_DA_Study/main/Week%202/spi_matches_latest.csv")

# 모든 컬럼 출력
print("전체 컬럼:")
print(df.columns)

# 특정 컬럼 선택
selected_columns = ["season", "date", "league", "team1", "team2", "score1", "score2"]

# 데이터프레임 업데이트
df_selected = df[selected_columns]

# 결과 출력
print("\n선택된 컬럼으로 업데이트된 데이터프레임:")
print(df_selected.head())
# Out:
# 전체 컬럼:
# Index(['season', 'date', 'league_id', 'league', 'team1', 'team2', 'spi1',
#        'spi2', 'prob1', 'prob2', 'probtie', 'proj_score1', 'proj_score2',
#        'importance1', 'importance2', 'score1', 'score2', 'xg1', 'xg2', 'nsxg1',
#        'nsxg2', 'adj_score1', 'adj_score2'],
#       dtype='object')
#
# 선택된 컬럼으로 업데이트된 데이터프레임:
#    season        date                league                 team1  \
# 0    2019  2019-03-01  Chinese Super League       Shandong Luneng
# 1    2019  2019-03-01  Chinese Super League    Shanghai Greenland
# 2    2019  2019-03-01  Chinese Super League  Guangzhou Evergrande
# 3    2019  2019-03-01  Chinese Super League            Wuhan Zall
# 4    2019  2019-03-01  Chinese Super League       Chongqing Lifan
#
#                team2  score1  score2
# 0      Guizhou Renhe     1.0     0.0
# 1      Shanghai SIPG     0.0     4.0
# 2  Tianjin Quanujian     3.0     0.0
# 3      Beijing Guoan     0.0     1.0
# 4       Guangzhou RF     2.0     2.0

# %% [markdown]
# ### 3-2. Barclays Premier League 경기의 홈팀과 원정팀의 득점 분포를 각각 구하시오.
#
# - describe 메소드 또는 value_counts 메소드 등을 활용할 수 있는데, 어떤 메소드를 활용하는 것이 좋을지 생각 후 결정해보기 (정답은 없음)

# %%
best_df = df[df['league'] == 'Barclays Premier League']

# 홈팀 득점
home_team_scores_counts = bpl_df['score1'].value_counts().sort_index()

# 원정팀 득점
neighbor_team_scores_counts = bpl_df['score2'].value_counts().sort_index()


print("\n홈팀 득점 분포:")
print(home_team_scores_counts)

print("\n원정팀 득점 분포:")
print(neighbor_team_scores_counts)
# Out:
# 홈팀 득점 분포:
# 0.0     82
# 1.0    124
# 2.0     90
# 3.0     43
# 4.0     28
# 5.0      6
# 6.0      5
# 7.0      1
# 9.0      1
# Name: score1, dtype: int64
#
# 원정팀 득점 분포:
# 0.0    125
# 1.0    125
# 2.0     76
# 3.0     35
# 4.0     15
# 5.0      3
# 6.0      1
# Name: score2, dtype: int64

# %% [markdown]
# ### 4. Everton, Tottenham Hotspur, Atletico Madrid 팀의 모든 경기를 출력하시오.
#
# > 주의사항 : 홈 경기와 원정 경기를 모두 출력해야 함

# %%
## 밑에 코드 작성

# Everton, Tottenham Hotspur, Atletico Madrid 팀의 모든 경기 출력
selected_teams = ['Everton', 'Tottenham Hotspur', 'Atletico Madrid']
selected_matches = df[df['team1'].isin(selected_teams) | df['team2'].isin(selected_teams)]

# 결과 출력
print(selected_matches)
# Out:
#        season        date  league_id                    league  \
# 557      2022  2022-08-06       2411   Barclays Premier League
# 572      2022  2022-08-06       2411   Barclays Premier League
# 686      2022  2022-08-13       2411   Barclays Premier League
# 827      2022  2022-08-14       2411   Barclays Premier League
# 862      2022  2022-08-15       1869  Spanish Primera Division
# ...       ...         ...        ...                       ...
# 9822     2022  2023-05-24       1869  Spanish Primera Division
# 9998     2022  2023-05-28       2411   Barclays Premier League
# 10000    2022  2023-05-28       2411   Barclays Premier League
# 10011    2022  2023-05-28       1869  Spanish Primera Division
# 10210    2022  2023-06-04       1869  Spanish Primera Division
#
#                    team1              team2   spi1   spi2   prob1   prob2  \
# 557    Tottenham Hotspur        Southampton  81.87  61.33  0.7059  0.1182
# ...

# %% [markdown]
# - 정답 : 총 126개 행이 나와야 함

# %% [markdown]
# ### 5. 세 팀이 2023년에 이긴 모든 경기를 출력하시오.
#
# - 4번 문제 정답을 새 변수로 정의하면 더 편하게 할 수 있음

# %%
## 밑에 코드 작성
# 4번 문제 정답을 새 변수로 정의
selected_teams = ['Everton', 'Tottenham Hotspur', 'Atletico Madrid']
selected_matches = df[df['team1'].isin(selected_teams) | df['team2'].isin(selected_teams)]

# 2023년에 이긴 경기
win2023 = selected_matches[(selected_matches['date'].str.startswith('2023')) & (selected_matches['score1'] > selected_matches['score2'])]
print(win2023)
# Out:
#        season        date  league_id                    league  \
# 4917     2022  2023-01-19       2411   Barclays Premier League
# 4961     2022  2023-01-21       2411   Barclays Premier League
# 4995     2022  2023-01-21       1869  Spanish Primera Division
# 5371     2022  2023-02-04       2411   Barclays Premier League
# 5518     2022  2023-02-05       2411   Barclays Premier League
# 5613     2022  2023-02-11       2411   Barclays Premier League
# 5756     2022  2023-02-13       2411   Barclays Premier League
# 5789     2022  2023-02-14       1818     UEFA Champions League
# 5918     2022  2023-02-18       2411   Barclays Premier League
# 6016     2022  2023-02-19       2411   Barclays Premier League
# 6020     2022  2023-02-19       1869  Spanish Primera Division
# 6259     2022  2023-02-26       2411   Barclays Premier League
# 6346     2022  2023-03-01       2411   Barclays Premier League
# 6440     2022  2023-03-04       2411   Barclays Premier League
# ...
