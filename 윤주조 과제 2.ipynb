# %% [markdown]
# ## 5 ~ 6번 문제
# [가져온 데이터_BLACK FRIDAY SALE]
#
# - 목표:
#
# "ABC Private Limited"라는 회사에서 여러 카테고리의 다양한 제품에 대한 고객 구매 행동(구체적으로 구매 금액)을 이해하고 고객들에게 개인화된 제안을 하려고 함
#
# - 수집 방법:
#
# 고객들의 구매 내역 공유
#
# - 데이터 내용:
#
# 고객의 인구통계(나이, 성별, 결혼 여부, 도시 유형, 현재 거주 도시), 제품 세부 정보(제품 ID및 제품 카테고리) 및 지난 달의 총 구매 금액 포함

# %% [markdown]
# ### 5. 카테고리 변수가 존재하는 데이터를 수집하여, 더미변수화하세요.

# %%
#데이터 불러오기
import pandas as pd

# file_path = 'C:\\Users\\jyjj0\\OneDrive\\바탕 화면\\Algorithm Study\\231122발제\\train.csv'
# data = pd.read_csv(file_path)

# # 데이터 확인
# print(data())

print(data.head())

##여기서 범주형은 'City_Category','Gender' 정도...?
# Out:
#   Gender
# 0      F
# 1      M

# %%
# !pip install patsy

import pandas as pd
from patsy import dmatrix
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Gender 더미변수화

data = pd.DataFrame(["F","M"], columns=["Gender"])
data
# Out:
#   Gender
# 0      F
# 1      M

# %%
dmatrix("Gender+ 0", data)
# Out:
# DesignMatrix with shape (2, 2)
#   Gender[F]  Gender[M]
#           1          0
#           0          1
#   Terms:
#     'Gender' (columns 0:2)

# %%
#City_Category 더미변수화

data2 = pd.DataFrame(["A", "B", "C"], columns=["City_Category"])
data2
# Out:
#   City_Category
# 0             A
# 1             B
# 2             C

# %%
dmatrix("City_Category+ 0", data2)
# Out:
# DesignMatrix with shape (3, 3)
#   City_Category[A]  City_Category[B]  City_Category[C]
#                  1                 0                 0
#                  0                 1                 0
#                  0                 0                 1
#   Terms:
#     'City_Category' (columns 0:3)

# %% [markdown]
# ### 6. 각 변수의 결측치를 missingno 패키지를 통해 확인하세요.

# %%
# !pip install missingno
# !pip install pandas
import pandas as pd

import matplotlib.pyplot as plt

#데이터가 어디에 존재하나?
import missingno as msno

msno.matrix(data)
plt.show()
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
# 데이터가 얼마나 존재하나?

msno.bar(data)
plt.show()
